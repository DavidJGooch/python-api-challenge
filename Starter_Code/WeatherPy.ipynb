# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
print(weather_api_key)
# Out:
# c0433a2c5d9b733975eece8f423fa31e

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url ="http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | kouango
# Processing Record 4 of Set 1 | nuuk
# Processing Record 5 of Set 1 | ewo
# Processing Record 6 of Set 1 | maridi
# Processing Record 7 of Set 1 | tulchyn
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | acarau
# Processing Record 10 of Set 1 | troy
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | nakskov
# Processing Record 14 of Set 1 | tokar
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | badger
# Processing Record 18 of Set 1 | grytviken
# Processing Record 19 of Set 1 | jertih
# Processing Record 20 of Set 1 | hays
# Processing Record 21 of Set 1 | bilibino
# Processing Record 22 of Set 1 | itacare
# Processing Record 23 of Set 1 | enewetak
# Processing Record 24 of Set 1 | constantia
# Processing Record 25 of Set 1 | papatowai
# Processing Record 26 of Set 1 | ola
# Processing Record 27 of Set 1 | taro
# Processing Record 28 of Set 1 | ilulissat
# Processing Record 29 of Set 1 | howrah
# Processing Record 30 of Set 1 | tura
# Processing Record 31 of Set 1 | bryne
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | lazaro cardenas
# Processing Record 34 of Set 1 | atafu village
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | blackmans bay
# Processing Record 37 of Set 1 | al bawiti
# Processing Record 38 of Set 1 | qarazhal
# Processing Record 39 of Set 1 | flying fish cove
# Processing Record 40 of Set 1 | waitangi
# Processing Record 41 of Set 1 | george town
# Processing Record 42 of Set 1 | st. john's
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | klyuchi
# Processing Record 45 of Set 1 | west island
# Processing Record 46 of Set 1 | chengde
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | saipan
# Processing Record 49 of Set 1 | garissa
# Processing Record 50 of Set 1 | ust-nera
# Processing Record 0 of Set 2 | brak
# Processing Record 1 of Set 2 | thunder bay
# Processing Record 2 of Set 2 | grand baie
# Processing Record 3 of Set 2 | port mathurin
# Processing Record 4 of Set 2 | broome
# Processing Record 5 of Set 2 | kousa
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | itaituba
# Processing Record 8 of Set 2 | kerikeri
# Processing Record 9 of Set 2 | dudinka
# Processing Record 10 of Set 2 | oranjemund
# Processing Record 11 of Set 2 | lihue
# Processing Record 12 of Set 2 | port saint john's
# Processing Record 13 of Set 2 | fale old settlement
# Processing Record 14 of Set 2 | isafjordur
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | coquimbo
# Processing Record 17 of Set 2 | tarauaca
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | hamilton
# Processing Record 21 of Set 2 | kadugli
# Processing Record 22 of Set 2 | margaret river
# Processing Record 23 of Set 2 | katsuura
# Processing Record 24 of Set 2 | hermanus
# Processing Record 25 of Set 2 | curuzu cuatia
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | san martin
# Processing Record 28 of Set 2 | olonkinbyen
# Processing Record 29 of Set 2 | olpad
# Processing Record 30 of Set 2 | colonia
# Processing Record 31 of Set 2 | puerto natales
# Processing Record 32 of Set 2 | vrangel'
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | tazovsky
# Processing Record 35 of Set 2 | la ronge
# Processing Record 36 of Set 2 | whitehorse
# Processing Record 37 of Set 2 | nicoya
# Processing Record 38 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 39 of Set 2 | kafir qala
# Processing Record 40 of Set 2 | leh
# Processing Record 41 of Set 2 | mejit
# Processing Record 42 of Set 2 | gaalkacyo
# Processing Record 43 of Set 2 | vila velha
# Processing Record 44 of Set 2 | huinca renanco
# Processing Record 45 of Set 2 | san andres
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | tsiombe
# Processing Record 48 of Set 2 | portoferraio
# Processing Record 49 of Set 2 | hawaiian paradise park
# Processing Record 0 of Set 3 | shingu
# Processing Record 1 of Set 3 | uturoa
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | puerto aysen
# Processing Record 4 of Set 3 | kone
# Processing Record 5 of Set 3 | udalguri
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | zaragoza
# Processing Record 8 of Set 3 | mount gambier
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | rovaniemi
# Processing Record 11 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 12 of Set 3 | mata-utu
# Processing Record 13 of Set 3 | akureyri
# Processing Record 14 of Set 3 | revda
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | happy valley-goose bay
# Processing Record 17 of Set 3 | khandyga
# Processing Record 18 of Set 3 | longyearbyen
# Processing Record 19 of Set 3 | quellon
# Processing Record 20 of Set 3 | san pedro pochutla
# Processing Record 21 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 22 of Set 3 | vilyuchinsk
# Processing Record 23 of Set 3 | san antonio de pale
# Processing Record 24 of Set 3 | masterton
# Processing Record 25 of Set 3 | palangkaraya
# Processing Record 26 of Set 3 | wailua homesteads
# Processing Record 27 of Set 3 | isangel
# Processing Record 28 of Set 3 | aasiaat
# Processing Record 29 of Set 3 | zwedru
# Processing Record 30 of Set 3 | fiambala
# Processing Record 31 of Set 3 | marka
# Processing Record 32 of Set 3 | haiku-pauwela
# Processing Record 33 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 34 of Set 3 | ko pha ngan
# Processing Record 35 of Set 3 | kapuskasing
# Processing Record 36 of Set 3 | boende
# Processing Record 37 of Set 3 | bingol
# Processing Record 38 of Set 3 | prince rupert
# Processing Record 39 of Set 3 | utrik
# Processing Record 40 of Set 3 | castanos
# Processing Record 41 of Set 3 | la passe
# Processing Record 42 of Set 3 | slave lake
# Processing Record 43 of Set 3 | remire-montjoly
# Processing Record 44 of Set 3 | rabo de peixe
# Processing Record 45 of Set 3 | college
# Processing Record 46 of Set 3 | detva
# Processing Record 47 of Set 3 | pahrump
# Processing Record 48 of Set 3 | holualoa
# Processing Record 49 of Set 3 | baker city
# Processing Record 0 of Set 4 | kinablangan
# Processing Record 1 of Set 4 | glencoe
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | chonchi
# Processing Record 4 of Set 4 | nova vicosa
# Processing Record 5 of Set 4 | spearfish
# Processing Record 6 of Set 4 | tromso
# Processing Record 7 of Set 4 | meiktila
# Processing Record 8 of Set 4 | otjimbingwe
# Processing Record 9 of Set 4 | vilyuysk
# Processing Record 10 of Set 4 | tekeli
# Processing Record 11 of Set 4 | karratha
# Processing Record 12 of Set 4 | prescott
# Processing Record 13 of Set 4 | carnarvon
# Processing Record 14 of Set 4 | bayanhongor
# Processing Record 15 of Set 4 | iskateley
# Processing Record 16 of Set 4 | richards bay
# Processing Record 17 of Set 4 | bredasdorp
# Processing Record 18 of Set 4 | kitami
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | touros
# Processing Record 21 of Set 4 | newman
# Processing Record 22 of Set 4 | walvis bay
# Processing Record 23 of Set 4 | mount isa
# Processing Record 24 of Set 4 | ardakan
# Processing Record 25 of Set 4 | nova sintra
# Processing Record 26 of Set 4 | guachochi
# City not found. Skipping...
# Processing Record 27 of Set 4 | smithers
# Processing Record 28 of Set 4 | zaozersk
# Processing Record 29 of Set 4 | palasa
# Processing Record 30 of Set 4 | kalaleh
# Processing Record 31 of Set 4 | al kharijah
# Processing Record 32 of Set 4 | carutapera
# Processing Record 33 of Set 4 | vorgashor
# Processing Record 34 of Set 4 | choma
# Processing Record 35 of Set 4 | lerwick
# Processing Record 36 of Set 4 | cruzeiro do sul
# Processing Record 37 of Set 4 | shache
# Processing Record 38 of Set 4 | reggane
# Processing Record 39 of Set 4 | aquin
# Processing Record 40 of Set 4 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 41 of Set 4 | krasnoye-na-volge
# Processing Record 42 of Set 4 | manistee
# Processing Record 43 of Set 4 | pisco
# Processing Record 44 of Set 4 | kingston
# Processing Record 45 of Set 4 | abu zabad
# Processing Record 46 of Set 4 | susuman
# Processing Record 47 of Set 4 | udachny
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | guiuan
# Processing Record 0 of Set 5 | leskovac
# Processing Record 1 of Set 5 | arauca
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | mirpur mathelo
# Processing Record 4 of Set 5 | orchard homes
# Processing Record 5 of Set 5 | shahganj
# Processing Record 6 of Set 5 | la sarre
# Processing Record 7 of Set 5 | kyzylorda
# Processing Record 8 of Set 5 | nan
# Processing Record 9 of Set 5 | tolanaro
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | tachilek
# City not found. Skipping...
# Processing Record 12 of Set 5 | klaksvik
# Processing Record 13 of Set 5 | cabo san lucas
# Processing Record 14 of Set 5 | praia da vitoria
# Processing Record 15 of Set 5 | cill airne
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | nizhniy odes
# Processing Record 18 of Set 5 | orkney
# Processing Record 19 of Set 5 | qaqortoq
# Processing Record 20 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 21 of Set 5 | medicine hat
# Processing Record 22 of Set 5 | itoman
# Processing Record 23 of Set 5 | sur
# Processing Record 24 of Set 5 | solnechnyy
# Processing Record 25 of Set 5 | saint-louis
# Processing Record 26 of Set 5 | puerto armuelles
# Processing Record 27 of Set 5 | talnakh
# Processing Record 28 of Set 5 | kununurra
# Processing Record 29 of Set 5 | stephenville
# Processing Record 30 of Set 5 | saudarkrokur
# Processing Record 31 of Set 5 | new norfolk
# Processing Record 32 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 33 of Set 5 | sovetskaya gavan'
# Processing Record 34 of Set 5 | springbok
# Processing Record 35 of Set 5 | vorkuta
# Processing Record 36 of Set 5 | arno
# Processing Record 37 of Set 5 | fada
# Processing Record 38 of Set 5 | madalena
# Processing Record 39 of Set 5 | illela
# Processing Record 40 of Set 5 | tamanrasset
# Processing Record 41 of Set 5 | kourou
# Processing Record 42 of Set 5 | bardai
# Processing Record 43 of Set 5 | kavaratti
# Processing Record 44 of Set 5 | punta arenas
# Processing Record 45 of Set 5 | bay roberts
# Processing Record 46 of Set 5 | pionerskiy
# Processing Record 47 of Set 5 | altay
# Processing Record 48 of Set 5 | ciudad bolivar
# Processing Record 49 of Set 5 | minacu
# City not found. Skipping...
# Processing Record 0 of Set 6 | cabedelo
# Processing Record 1 of Set 6 | hilton head island
# Processing Record 2 of Set 6 | lobujya
# Processing Record 3 of Set 6 | tralee
# Processing Record 4 of Set 6 | ak-dovurak
# Processing Record 5 of Set 6 | charters towers
# Processing Record 6 of Set 6 | lake havasu city
# Processing Record 7 of Set 6 | puerto ayora
# Processing Record 8 of Set 6 | atar
# Processing Record 9 of Set 6 | laguna
# Processing Record 10 of Set 6 | carauari
# Processing Record 11 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 12 of Set 6 | taggia
# Processing Record 13 of Set 6 | evanston
# Processing Record 14 of Set 6 | al burayqah
# Processing Record 15 of Set 6 | tabou
# Processing Record 16 of Set 6 | callao
# Processing Record 17 of Set 6 | olyokminsk
# Processing Record 18 of Set 6 | la libertad
# Processing Record 19 of Set 6 | fomento
# Processing Record 20 of Set 6 | al muwayh
# Processing Record 21 of Set 6 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | bafoulabe
# Processing Record 23 of Set 6 | swanage
# Processing Record 24 of Set 6 | invercargill
# Processing Record 25 of Set 6 | garh maharaja
# Processing Record 26 of Set 6 | rusk
# Processing Record 27 of Set 6 | kristiansund
# Processing Record 28 of Set 6 | tazacorte
# Processing Record 29 of Set 6 | marsala
# Processing Record 30 of Set 6 | qamdo
# Processing Record 31 of Set 6 | keflavik
# Processing Record 32 of Set 6 | crucecita
# Processing Record 33 of Set 6 | newnham
# Processing Record 34 of Set 6 | kapiri mposhi
# Processing Record 35 of Set 6 | shiyan
# Processing Record 36 of Set 6 | bafra
# Processing Record 37 of Set 6 | mil'kovo
# Processing Record 38 of Set 6 | mek'ele
# Processing Record 39 of Set 6 | ebon
# Processing Record 40 of Set 6 | tobi village
# City not found. Skipping...
# Processing Record 41 of Set 6 | labrador city
# Processing Record 42 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 43 of Set 6 | yengema
# Processing Record 44 of Set 6 | carupano
# Processing Record 45 of Set 6 | dongsheng
# Processing Record 46 of Set 6 | kailua-kona
# Processing Record 47 of Set 6 | toledo
# Processing Record 48 of Set 6 | okondja
# Processing Record 49 of Set 6 | tocopilla
# Processing Record 0 of Set 7 | horta
# Processing Record 1 of Set 7 | sitka
# Processing Record 2 of Set 7 | tondano
# Processing Record 3 of Set 7 | ducheng
# Processing Record 4 of Set 7 | prado
# Processing Record 5 of Set 7 | teknaf
# Processing Record 6 of Set 7 | el daein
# City not found. Skipping...
# Processing Record 7 of Set 7 | lucapa
# Processing Record 8 of Set 7 | yuzhno-kurilsk
# Processing Record 9 of Set 7 | padangsidempuan
# Processing Record 10 of Set 7 | bolobo
# Processing Record 11 of Set 7 | dryden
# Processing Record 12 of Set 7 | amurzet
# Processing Record 13 of Set 7 | barakani
# Processing Record 14 of Set 7 | sinabang
# Processing Record 15 of Set 7 | nagqu
# Processing Record 16 of Set 7 | siparia
# Processing Record 17 of Set 7 | nemuro
# Processing Record 18 of Set 7 | sokoni
# Processing Record 19 of Set 7 | antofagasta
# Processing Record 20 of Set 7 | bandarbeyla
# Processing Record 21 of Set 7 | northam
# Processing Record 22 of Set 7 | sampit
# Processing Record 23 of Set 7 | fallon
# Processing Record 24 of Set 7 | fort bragg
# Processing Record 25 of Set 7 | plettenberg bay
# Processing Record 26 of Set 7 | stanley
# Processing Record 27 of Set 7 | la'ie
# Processing Record 28 of Set 7 | opuwo
# Processing Record 29 of Set 7 | ellon
# Processing Record 30 of Set 7 | yaren
# Processing Record 31 of Set 7 | chhor
# Processing Record 32 of Set 7 | mushie
# Processing Record 33 of Set 7 | pauini
# Processing Record 34 of Set 7 | malango
# Processing Record 35 of Set 7 | rouissat
# Processing Record 36 of Set 7 | puerto deseado
# Processing Record 37 of Set 7 | santa cruz
# Processing Record 38 of Set 7 | immokalee
# Processing Record 39 of Set 7 | maiwut
# City not found. Skipping...
# Processing Record 40 of Set 7 | afaahiti
# Processing Record 41 of Set 7 | ambovombe
# Processing Record 42 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 43 of Set 7 | lindi
# Processing Record 44 of Set 7 | oodweyne
# Processing Record 45 of Set 7 | springfield
# Processing Record 46 of Set 7 | egilsstadir
# Processing Record 47 of Set 7 | tome
# Processing Record 48 of Set 7 | taroa
# Processing Record 49 of Set 7 | tianshui
# Processing Record 0 of Set 8 | cidreira
# Processing Record 1 of Set 8 | puerto san jose
# Processing Record 2 of Set 8 | gaiman
# Processing Record 3 of Set 8 | puerto baquerizo moreno
# Processing Record 4 of Set 8 | linxia chengguanzhen
# Processing Record 5 of Set 8 | garcia
# Processing Record 6 of Set 8 | balqash
# Processing Record 7 of Set 8 | oyama
# Processing Record 8 of Set 8 | ad dabbah
# Processing Record 9 of Set 8 | eyl
# Processing Record 10 of Set 8 | vuktyl
# Processing Record 11 of Set 8 | motygino
# Processing Record 12 of Set 8 | castillos
# Processing Record 13 of Set 8 | moisei
# Processing Record 14 of Set 8 | dapchi
# Processing Record 15 of Set 8 | broken hill
# Processing Record 16 of Set 8 | magdagachi
# Processing Record 17 of Set 8 | basco
# Processing Record 18 of Set 8 | north nowra
# Processing Record 19 of Set 8 | espiye
# Processing Record 20 of Set 8 | ouellah
# City not found. Skipping...
# Processing Record 21 of Set 8 | ulsteinvik
# Processing Record 22 of Set 8 | port-cartier
# Processing Record 23 of Set 8 | afif
# Processing Record 24 of Set 8 | gwio kura
# Processing Record 25 of Set 8 | yoichi
# Processing Record 26 of Set 8 | cartagena
# Processing Record 27 of Set 8 | longboat key
# Processing Record 28 of Set 8 | jamjamal
# Processing Record 29 of Set 8 | beau vallon
# Processing Record 30 of Set 8 | nelson
# Processing Record 31 of Set 8 | anna
# Processing Record 32 of Set 8 | hilo
# Processing Record 33 of Set 8 | east london
# Processing Record 34 of Set 8 | laghouat
# Processing Record 35 of Set 8 | minas de marcona
# Processing Record 36 of Set 8 | nar'yan-mar
# Processing Record 37 of Set 8 | akrehamn
# Processing Record 38 of Set 8 | san patricio
# Processing Record 39 of Set 8 | bel ombre
# Processing Record 40 of Set 8 | barra do corda
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | bologoye-4
# City not found. Skipping...
# Processing Record 43 of Set 8 | miri
# Processing Record 44 of Set 8 | itamaraca
# Processing Record 45 of Set 8 | kapoeta
# Processing Record 46 of Set 8 | kiselevsk
# Processing Record 47 of Set 8 | chiredzi
# Processing Record 48 of Set 8 | awjilah
# Processing Record 49 of Set 8 | xapuri
# Processing Record 0 of Set 9 | olinda
# Processing Record 1 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 2 of Set 9 | mossel bay
# Processing Record 3 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 4 of Set 9 | wenling
# Processing Record 5 of Set 9 | bumba
# Processing Record 6 of Set 9 | paita
# Processing Record 7 of Set 9 | mong cai
# City not found. Skipping...
# Processing Record 8 of Set 9 | el nido
# Processing Record 9 of Set 9 | ponta delgada
# Processing Record 10 of Set 9 | puerto san carlos
# City not found. Skipping...
# Processing Record 11 of Set 9 | tataouine
# Processing Record 12 of Set 9 | challapata
# Processing Record 13 of Set 9 | vyazemskiy
# Processing Record 14 of Set 9 | kuching
# Processing Record 15 of Set 9 | tenenkou
# Processing Record 16 of Set 9 | margate
# Processing Record 17 of Set 9 | kalmunai
# Processing Record 18 of Set 9 | sambava
# Processing Record 19 of Set 9 | dunedin
# Processing Record 20 of Set 9 | yatou
# Processing Record 21 of Set 9 | chibougamau
# Processing Record 22 of Set 9 | kirensk
# Processing Record 23 of Set 9 | rongelap
# Processing Record 24 of Set 9 | alice springs
# Processing Record 25 of Set 9 | puerto escondido
# Processing Record 26 of Set 9 | nema
# Processing Record 27 of Set 9 | qulsary
# Processing Record 28 of Set 9 | papao
# Processing Record 29 of Set 9 | gadzhiyevo
# Processing Record 30 of Set 9 | mont-dore
# Processing Record 31 of Set 9 | mohr
# Processing Record 32 of Set 9 | chiili
# City not found. Skipping...
# Processing Record 33 of Set 9 | karatuzskoye
# Processing Record 34 of Set 9 | nainpur
# Processing Record 35 of Set 9 | gallivare
# City not found. Skipping...
# Processing Record 36 of Set 9 | general pinedo
# Processing Record 37 of Set 9 | freetown
# Processing Record 38 of Set 9 | champerico
# Processing Record 39 of Set 9 | kaliua
# Processing Record 40 of Set 9 | nacozari viejo
# Processing Record 41 of Set 9 | north battleford
# Processing Record 42 of Set 9 | mount pearl
# Processing Record 43 of Set 9 | mili
# Processing Record 44 of Set 9 | radeburg
# Processing Record 45 of Set 9 | santarem
# Processing Record 46 of Set 9 | ketou
# Processing Record 47 of Set 9 | santa croce camerina
# Processing Record 48 of Set 9 | morehead city
# Processing Record 49 of Set 9 | wenatchee
# Processing Record 0 of Set 10 | katiola
# Processing Record 1 of Set 10 | hadibu
# Processing Record 2 of Set 10 | ad-damazin
# Processing Record 3 of Set 10 | alaghsas
# Processing Record 4 of Set 10 | naryn
# Processing Record 5 of Set 10 | renk
# City not found. Skipping...
# Processing Record 6 of Set 10 | kawalu
# Processing Record 7 of Set 10 | isla vista
# Processing Record 8 of Set 10 | brookings
# Processing Record 9 of Set 10 | nchelenge
# Processing Record 10 of Set 10 | rurrenabaque
# Processing Record 11 of Set 10 | elkins
# Processing Record 12 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 10 | rio grande
# Processing Record 14 of Set 10 | cacheu
# Processing Record 15 of Set 10 | macouria
# Processing Record 16 of Set 10 | manokwari
# Processing Record 17 of Set 10 | homocea
# Processing Record 18 of Set 10 | kansanshi
# Processing Record 19 of Set 10 | dieppe
# Processing Record 20 of Set 10 | bwizibwera
# Processing Record 21 of Set 10 | taltal
# Processing Record 22 of Set 10 | wapi pathum
# Processing Record 23 of Set 10 | prince george
# Processing Record 24 of Set 10 | glasgow
# Processing Record 25 of Set 10 | vimmerby
# Processing Record 26 of Set 10 | shagonar
# Processing Record 27 of Set 10 | molde
# Processing Record 28 of Set 10 | port-vila
# Processing Record 29 of Set 10 | ilam
# Processing Record 30 of Set 10 | yorkton
# Processing Record 31 of Set 10 | pacific grove
# Processing Record 32 of Set 10 | tabuk
# Processing Record 33 of Set 10 | codrington
# Processing Record 34 of Set 10 | hastings
# Processing Record 35 of Set 10 | tangalle
# Processing Record 36 of Set 10 | verkhovazh'ye
# Processing Record 37 of Set 10 | mo i rana
# Processing Record 38 of Set 10 | nadi
# Processing Record 39 of Set 10 | tofol
# Processing Record 40 of Set 10 | eastham
# Processing Record 41 of Set 10 | merritt
# Processing Record 42 of Set 10 | amfissa
# Processing Record 43 of Set 10 | ugoofaaru
# Processing Record 44 of Set 10 | fort st. john
# Processing Record 45 of Set 10 | kapa'a
# Processing Record 46 of Set 10 | lesnoy
# Processing Record 47 of Set 10 | queenstown
# Processing Record 48 of Set 10 | kushiro
# Processing Record 49 of Set 10 | necochea
# Processing Record 0 of Set 11 | bijar
# Processing Record 1 of Set 11 | ta`u
# Processing Record 2 of Set 11 | diguvametta
# City not found. Skipping...
# Processing Record 3 of Set 11 | arkhangel'sk
# Processing Record 4 of Set 11 | ilheus
# Processing Record 5 of Set 11 | musan-up
# Processing Record 6 of Set 11 | vila franca do campo
# Processing Record 7 of Set 11 | hawera
# Processing Record 8 of Set 11 | usogorsk
# Processing Record 9 of Set 11 | wenchang
# Processing Record 10 of Set 11 | mount darwin
# Processing Record 11 of Set 11 | biltine
# Processing Record 12 of Set 11 | luderitz
# Processing Record 13 of Set 11 | revelstoke
# Processing Record 14 of Set 11 | mana
# Processing Record 15 of Set 11 | den helder
# Processing Record 16 of Set 11 | akobo
# Processing Record 17 of Set 11 | dalnegorsk
# Processing Record 18 of Set 11 | caleta de carquin
# Processing Record 19 of Set 11 | kalymnos
# Processing Record 20 of Set 11 | zeya
# Processing Record 21 of Set 11 | isiro
# Processing Record 22 of Set 11 | georgievka
# Processing Record 23 of Set 11 | sala
# Processing Record 24 of Set 11 | rio gallegos
# Processing Record 25 of Set 11 | jackson
# Processing Record 26 of Set 11 | port lincoln
# Processing Record 27 of Set 11 | chemolgan
# Processing Record 28 of Set 11 | sittwe
# Processing Record 29 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 30 of Set 11 | camocim
# Processing Record 31 of Set 11 | timbuktu
# Processing Record 32 of Set 11 | selfoss
# Processing Record 33 of Set 11 | boa vista
# Processing Record 34 of Set 11 | borgarnes
# Processing Record 35 of Set 11 | sarangani
# Processing Record 36 of Set 11 | ixtapa
# Processing Record 37 of Set 11 | christchurch
# Processing Record 38 of Set 11 | saratamata
# City not found. Skipping...
# Processing Record 39 of Set 11 | mohammedia
# Processing Record 40 of Set 11 | san jose de jachal
# Processing Record 41 of Set 11 | villa gesell
# Processing Record 42 of Set 11 | sirjan
# Processing Record 43 of Set 11 | lobito
# Processing Record 44 of Set 11 | gazli
# Processing Record 45 of Set 11 | idri
# Processing Record 46 of Set 11 | ganjam
# Processing Record 47 of Set 11 | sultanah
# Processing Record 48 of Set 11 | el obeid
# Processing Record 49 of Set 11 | mandiana
# Processing Record 0 of Set 12 | jayapura
# Processing Record 1 of Set 12 | chanute
# Processing Record 2 of Set 12 | natal
# Processing Record 3 of Set 12 | huanuco
# Processing Record 4 of Set 12 | okhotsk
# Processing Record 5 of Set 12 | maralal
# Processing Record 6 of Set 12 | ono
# Processing Record 7 of Set 12 | ekibastuz
# Processing Record 8 of Set 12 | olonets
# Processing Record 9 of Set 12 | barra do garcas
# Processing Record 10 of Set 12 | santa marta de ortigueira
# Processing Record 11 of Set 12 | inekar
# City not found. Skipping...
# Processing Record 12 of Set 12 | manakara
# Processing Record 13 of Set 12 | conception bay south
# Processing Record 14 of Set 12 | peterhead
# Processing Record 15 of Set 12 | san luis de la loma
# Processing Record 16 of Set 12 | belmonte
# Processing Record 17 of Set 12 | narrabri
# Processing Record 18 of Set 12 | port isabel
# Processing Record 19 of Set 12 | agadez
# Processing Record 20 of Set 12 | ceeldheer
# Processing Record 21 of Set 12 | sarupathar
# Processing Record 22 of Set 12 | lhokseumawe
# Processing Record 23 of Set 12 | launceston
# Processing Record 24 of Set 12 | andergrove
# Processing Record 25 of Set 12 | tanrake village
# City not found. Skipping...
# Processing Record 26 of Set 12 | coahuayana de hidalgo
# Processing Record 27 of Set 12 | viedma
# Processing Record 28 of Set 12 | hit
# Processing Record 29 of Set 12 | taybad
# Processing Record 30 of Set 12 | domna
# Processing Record 31 of Set 12 | comodoro rivadavia
# Processing Record 32 of Set 12 | semey
# Processing Record 33 of Set 12 | gorgan
# Processing Record 34 of Set 12 | puerto colombia
# Processing Record 35 of Set 12 | ribeira brava
# Processing Record 36 of Set 12 | massawa
# Processing Record 37 of Set 12 | popondetta
# Processing Record 38 of Set 12 | trairi
# Processing Record 39 of Set 12 | labuan lombok
# City not found. Skipping...
# Processing Record 40 of Set 12 | santiago de cao
# Processing Record 41 of Set 12 | sint michiel liber
# Processing Record 42 of Set 12 | oualidia
# City not found. Skipping...
# Processing Record 43 of Set 12 | vernon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
 
# Show Record Count
city_data_df.count()
# Out:
# City          561
# Lat           561
# Lng           561
# Max Temp      561
# Humidity      561
# Cloudiness    561
# Wind Speed    561
# Country       561
# Date          561
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0             albany  42.6001 -73.9662      0.23        84         100
# 1  port-aux-francais -49.3500  70.2167      3.95        73          88
# 2            kouango   4.9934  19.9619     25.87        38         100
# 3               nuuk  64.1835 -51.7216     -9.66        62         100
# 4                ewo  -0.8725  14.8206     25.60        57         100
#
#    Wind Speed Country        Date
# 0        2.41      US  1706667299
# 1       14.22      TF  1706667299
# 2        0.42      CF  1706667299
# 3       12.07      GL  1706667000
# 4        1.11      CG  1706667299

# %%
# Export the City_Data into a csv
city_data_df.to_csv("C:/Users/djgoo/DataAnalysis/python-api-challenge/output_data/citiesdata.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("C:/Users/djgoo/DataAnalysis/python-api-challenge/output_data/citiesdata.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                   albany  42.6001 -73.9662      0.23        84         100
# 1        port-aux-francais -49.3500  70.2167      3.95        73          88
# 2                  kouango   4.9934  19.9619     25.87        38         100
# 3                     nuuk  64.1835 -51.7216     -9.66        62         100
# 4                      ewo  -0.8725  14.8206     25.60        57         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.41      US  1706667299
# 1             14.22      TF  1706667299
# 2              0.42      CF  1706667299
# 3             12.07      GL  1706667000
# 4              1.11      CG  1706667299

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Max Temp"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Celsius)")
plt.grid(True)
# Save the figure
plt.savefig("C:/Users/djgoo/DataAnalysis/python-api-challenge/output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Humidity"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)
# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)


# Save the figure
plt.savefig("C:/Users/djgoo/DataAnalysis/python-api-challenge/output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(     
    city_data_df["Lat"],
    city_data_df["Cloudiness"],
    edgecolor="black",
    linewidths=1,
    marker="o", 
    alpha=0.8,
    label="Cities"
)


# Incorporate the other graph properties
plt.title(("Latitude Vs. Amount of Cloud Cover (%s)") % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Amount of Cloud Cover (%)")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/djgoo/DataAnalysis/python-api-challenge/output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(    
   city_data_df["Lat"],
   city_data_df["Wind Speed"],
   edgecolor="black",
   linewidths=1,
   marker="o",
   alpha=0.8,
   label="Cities"
)
# Incorporate the other graph properties
plt.title(("Latitude Vs. Wind Speed (%s)") % time.strftime("%x"))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)
# Save the figure
plt.savefig("C:/Users/djgoo/DataAnalysis/python-api-challenge/output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
